# %% [markdown]
# # Preprocessing data (used for 2017-2022)

# %%
import pandas as pd

# %% [markdown]
# Read in all the data, using the year of the data as a key

# %%
dfs = {}
for i in range(2016, 2023):
    directory = f"Data//Headways_{i}"
    df = pd.read_csv(directory + ".csv")
    dfs[i] = df

# %%
for df in dfs:
    print(dfs[df].head())
# Out:
#            service_date route_id  direction_id  stop_id  start_time_sec  \
# 0  1/1/2016 12:00:00 AM     Blue             0    70041           24710
# 1  1/1/2016 12:00:00 AM     Blue             0    70041           25443
# 2  1/1/2016 12:00:00 AM     Blue             0    70041           26332
# 3  1/1/2016 12:00:00 AM     Blue             0    70041           26972
# 4  1/1/2016 12:00:00 AM     Blue             0    70041           27740
#
#    end_time_sec  headway_time_sec destination  ObjectId
# 0         25443               733     Bowdoin         1
# 1         26332               889     Bowdoin         2
# 2         26972               640     Bowdoin         3
# 3         27740               768     Bowdoin         4
# 4         28376               636     Bowdoin         5
#            service_date route_id  direction_id  stop_id  start_time_sec  \
# 0  1/1/2017 12:00:00 AM     Blue             0    70039           82949
# 1  1/1/2017 12:00:00 AM     Blue             0    70041           52304
# 2  1/1/2017 12:00:00 AM     Blue             0    70045           44441
# 3  1/1/2017 12:00:00 AM     Blue             0    70041           79506
# 4  1/1/2017 12:00:00 AM     Blue             0    70043           76718
#
#    end_time_sec  headway_time_sec destination  ObjectId
# 0         83760               811     Bowdoin         1
# 1         52794               490     Bowdoin         2
# 2         45028               587     Bowdoin         3
# 3         80213               707     Bowdoin         4
# 4         77240               522     Bowdoin         5
#            service_date route_id  direction_id  stop_id  start_time_sec  \
# 0  1/1/2018 12:00:00 AM     Blue             0    70039           24833
# 1  1/1/2018 12:00:00 AM     Blue             0    70039           25882
# 2  1/1/2018 12:00:00 AM     Blue             0    70039           34220
# 3  1/1/2018 12:00:00 AM     Blue             0    70039           35722
# 4  1/1/2018 12:00:00 AM     Blue             0    70039           36530
#
#    end_time_sec  headway_time_sec destination  ObjectId
# 0         25882              1049     Bowdoin         1
# 1         26589               707     Bowdoin         2
# 2         35722              1502     Bowdoin         3
# 3         36530               808     Bowdoin         4
# 4         37283               753     Bowdoin         5
#            service_date route_id  direction_id  stop_id  start_time_sec  \
# 0  1/1/2019 12:00:00 AM     Blue             0    70039           22890
# 1  1/1/2019 12:00:00 AM     Blue             0    70039           23290
# 2  1/1/2019 12:00:00 AM     Blue             0    70039           24120
# 3  1/1/2019 12:00:00 AM     Blue             0    70039           24935
# 4  1/1/2019 12:00:00 AM     Blue             0    70039           26062
#
#    end_time_sec  headway_time_sec destination  ObjectId
# 0         23290               400     Bowdoin         1
# 1         24120               830     Bowdoin         2
# 2         24935               815     Bowdoin         3
# 3         26062              1127     Bowdoin         4
# 4         26395               333     Bowdoin         5
#              service_date route_id  direction_id  stop_id  start_time_sec  \
# 0  2020/01/01 05:00:00+00     Blue             0    70049           27258
# 1  2020/01/01 05:00:00+00     Blue             0    70049           39944
# 2  2020/01/01 05:00:00+00     Blue             0    70049           42466
# 3  2020/01/01 05:00:00+00     Blue             0    70049           43058
# 4  2020/01/01 05:00:00+00     Blue             0    70049           43667
#
#    end_time_sec  headway_time_sec destination  ObjectId
# 0         28042               784     Bowdoin         1
# 1         40555               611     Bowdoin         2
# 2         43058               592     Bowdoin         3
# 3         43667               609     Bowdoin         4
# 4         44369               702     Bowdoin         5
#              service_date route_id  direction_id  stop_id  start_time_sec  \
# 0  2021/01/01 05:00:00+00     Blue             0    70041           30150
# 1  2021/01/01 05:00:00+00     Blue             0    70041           31682
# 2  2021/01/01 05:00:00+00     Blue             0    70041           34222
# 3  2021/01/01 05:00:00+00     Blue             0    70041           37861
# 4  2021/01/01 05:00:00+00     Blue             0    70041           38487
#
#    end_time_sec  headway_time_sec destination  ObjectId
# 0         30912               762     Bowdoin         1
# 1         32149               467     Bowdoin         2
# 2         34710               488     Bowdoin         3
# 3         38487               626     Bowdoin         4
# 4         39104               617     Bowdoin         5
#           service_date route_id  direction_id  stop_id  start_time_sec  \
# 0  1/1/2022 5:00:00 AM     Blue             0    70039           22617
# 1  1/1/2022 5:00:00 AM     Blue             0    70039           24998
# 2  1/1/2022 5:00:00 AM     Blue             0    70039           30364
# 3  1/1/2022 5:00:00 AM     Blue             0    70039           31234
# 4  1/1/2022 5:00:00 AM     Blue             0    70039           39240
#
#    end_time_sec  headway_time_sec destination  ObjectId  \
# 0         23344               727     Bowdoin         1
# 1         25688               690     Bowdoin         2
# 2         31234               870     Bowdoin         3
# 3         31875               641     Bowdoin         4
# 4         39877               637     Bowdoin         5
#
#                                GlobalID
# 0  9121318a-05ac-4214-9523-f7e2114d731d
# 1  fbae5852-7d93-4dd4-9dde-c8a13fe685ac
# 2  4f919f5e-d771-4b45-be5e-16d8cdfe9a2a
# 3  c08e4daa-c74b-4a11-9164-efc9f814df2f
# 4  b5ee9e94-8956-4ba3-80dc-e95d126e51d8

# %% [markdown]
# Group data by stop, direction, and destination.

# %%
for df in dfs:
    df_grouped = dfs[df].groupby(['stop_id', 'direction_id', 'destination']).agg({
        'headway_time_sec': 'mean'
    }).reset_index()
    dfs[df] = df_grouped
    print(df_grouped.head())
# Out:
#    stop_id  direction_id   destination  headway_time_sec
# 0    70001             1     Oak Grove        499.692239
# 1    70002             0  Forest Hills        509.656499
# 2    70003             1     Oak Grove        512.070998
# 3    70004             0  Forest Hills        506.538108
# 4    70005             1     Oak Grove        512.941418
#    stop_id  direction_id   destination  headway_time_sec
# 0    70001             1     Oak Grove        505.786136
# 1    70002             0  Forest Hills        505.573351
# 2    70003             1     Oak Grove        507.114465
# 3    70004             0  Forest Hills        505.320893
# 4    70005             1     Oak Grove        509.227303
#    stop_id  direction_id   destination  headway_time_sec
# 0    70001             0  Forest Hills       1056.137931
# 1    70001             1     Oak Grove        512.213911
# 2    70002             0  Forest Hills        519.718360
# 3    70003             1     Oak Grove        514.117837
# 4    70004             0  Forest Hills        519.019428
#    stop_id  direction_id   destination  headway_time_sec
# 0    70001             0  Forest Hills        684.672269
# 1    70001             1     Oak Grove        519.148623
# 2    70002             0  Forest Hills        521.140717
# 3    70003             1     Oak Grove        512.021927
# 4    70004             0  Forest Hills        521.435207
#    stop_id  direction_id   destination  headway_time_sec
# 0    70001             0  Forest Hills        560.257447
# 1    70001             1     Oak Grove        538.074998
# 2    70002             0  Forest Hills        539.821318
# 3    70003             1     Oak Grove        531.558340
# 4    70004             0  Forest Hills        540.200726
#    stop_id  direction_id   destination  headway_time_sec
# 0    70001             0  Forest Hills        532.000000
# 1    70001             1     Oak Grove        568.392724
# 2    70002             0  Forest Hills        569.730113
# 3    70003             1     Oak Grove        563.100133
# 4    70004             0  Forest Hills        570.394914
#    stop_id  direction_id   destination  headway_time_sec
# 0    70001             0  Forest Hills        547.000000
# 1    70001             1     Oak Grove        593.277430
# 2    70002             0  Forest Hills        589.646489
# 3    70003             1     Oak Grove        588.729268
# 4    70004             0  Forest Hills        590.257927

# %% [markdown]
# Check for null values

# %%
for df in dfs:
    print(dfs[df].isnull().sum())
# Out:
# stop_id             0
# direction_id        0
# destination         0
# headway_time_sec    0
# dtype: int64
# stop_id             0
# direction_id        0
# destination         0
# headway_time_sec    0
# dtype: int64
# stop_id             0
# direction_id        0
# destination         0
# headway_time_sec    0
# dtype: int64
# stop_id             0
# direction_id        0
# destination         0
# headway_time_sec    0
# dtype: int64
# stop_id             0
# direction_id        0
# destination         0
# headway_time_sec    0
# dtype: int64
# stop_id             0
# direction_id        0
# destination         0
# headway_time_sec    0
# dtype: int64
# stop_id             0
# direction_id        0
# destination         0
# headway_time_sec    0
# dtype: int64

# %% [markdown]
# # Creating stop_name column for data
#
# Using MBTA's GTFS stop.txt file

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv('stops.csv')

# Ensure that 'stop_id' is numeric and drop rows where 'stop_id' is not a valid number
df['stop_id'] = pd.to_numeric(df['stop_id'], errors='coerce')

# Drop rows where 'stop_id' is NaN (i.e., not numeric)
df = df.dropna(subset=['stop_id'])

# Convert 'stop_id' to integers
df['stop_id'] = df['stop_id'].astype(int)

# Create a dictionary with stop_id as keys and stop_name as values
stop_dict = pd.Series(df.stop_name.values, index=df.stop_id).to_dict()
stop_desc_dict = pd.Series(df.stop_desc.values, index=df.stop_id).to_dict()

# Print the resulting dictionary
print(stop_dict)
print(stop_desc_dict)
# Out:
# {1: 'Washington St opp Ruggles St', 10: 'Theo Glynn Way @ Newmarket Sq', 10000: 'Tremont St opp Temple Pl', 10003: 'Albany St opp Randall St', 10005: 'Albany St opp E Concord St', 10006: 'Albany St opp E Newton St', 10007: '540 Albany St opp Wareham St', 10008: 'Albany St opp Randolph St', 10009: 'High St @ Duck Lane', 10010: 'Southampton St @ Newmarket St', 10011: 'Albany St @ Randolph St', 10012: 'Albany St @ Wareham St', 10013: 'Albany St @ E Dedham St', 10014: 'Albany St opp Boston Medical', 10015: 'Harrison Ave @ E Newton St', 10016: 'TradeCenter 128', 10031: 'E 1st St @ P St', 10032: 'E 1st St opp O St', 10033: 'E 1st St @ O St', 101: 'Massachusetts Ave @ Sidney St', 10100: 'Albany St @ Randall St', 10101: 'Melnea Cass Blvd @ Harrison Ave', 102: 'Massachusetts Ave @ Prospect St', 1026: 'Chestnut Hill Ave @ Veronica Smith Ctr', 1027: 'Chestnut Hill Ave @ Englewood Ave', 1029: 'Chestnut Hill Ave @ Commonwealth Ave', 1030: 'Chestnut Hill Ave @ Strathmore Rd', 1032: 'Chestnut Hill Ave opp Wiltshire Rd', 1033: 'Chestnut Hill Ave @ Wallingford Rd', 1034: 'Chestnut Hill Ave @ Union St', 1035: 'Market St @ Washington St', 1036: 'Market St @ Sparhawk St', 1038: 'Market St @ Gardena St', 1039: 'Market St @ N Beacon St', 104: 'Massachusetts Ave @ Inman St', 1040: 'Market St @ Guest St', 1041: 'Market St @ Centola St', 10413: 'Columbus Ave @ Weld Ave - Egleston Sq', 10417: 'American Legion Hwy @ Blue Hill Ave', 10418: 'American Legion Hwy opp Franklin Hill Ave', 10419: 'American Legion Hwy @ Canterbury St', 1042: 'Market St @ Lothrop St', 10421: 'American Legion Hwy @ Walk Hill St', 10422: 'Opp 684 American Legion Hwy', 10423: 'American Legion Hwy @ Stella Rd', 10424: 'American Legion Hwy @ Cummins Hwy', 10425: 'Opp 950 American Legion Hwy', 10427: 'American Legion Hwy opp Kingbird Rd', 1043: 'Western Ave @ Mackin St', 1045: '450 Western Ave', 1046: 'Western Ave @ Litchfield St', 1049: 'Western Ave @ Everett St', 1051: 'Western Ave @ Travis St', 1052: '130 Western Ave', 10522: 'Circuit Dr @ Glen Ln', 1053: 'Western Ave @ Genzyme', 10540: 'Morton St @ Evans St', 1055: 'River St opp Blackstone St', 1056: 'River St @ Fairmont St', 10569: '2165 Dorchester Ave', 1057: 'River St @ Kelly Rd', 1058: 'River St opp Kinnaird St', 10582: 'River St opp Fremont St', 1059: 'River St @ Green St', 10590: 'Massachusetts Ave @ Washington St', 106: 'Massachusetts Ave @ Hancock St', 1060: 'Magazine St @ Green St', 10603: 'Washington St @ Durnell Ave', 1061: 'Western Ave @ Kinnaird St', 10612: 'Washington St opp W Boundary Rd', 10618: 'Washington St @ Sumner St', 1062: 'Western Ave @ Howard St', 10625: 'Washington St opp Heron St', 10633: 'Washington St @ Rosecliff St', 1064: 'Western Ave @ Putnam Ave', 1067: 'Western Ave opp Genzyme', 1068: '125 Western Ave', 107: 'Massachusetts Ave @ Dana St', 1070: 'Western Ave @ N Harvard St', 1071: 'Western Ave opp Riverdale St', 1072: 'Western Ave @ Everett St', 1074: '367 Western Ave opp Brighton Mills Mall', 1075: 'Western Ave opp Litchfield St', 1076: '445 Western Ave', 10768: 'Centre St @ Grove St', 10769: 'Centre St @ Grove St', 1077: '495 Western Ave', 10777: 'Spring St @ Cass St', 1079: 'Market St @ Vineland St', 108: 'Massachusetts Ave @ Trowbridge St', 1080: 'Market St @ N Beacon St', 1081: 'Market St @ Keenan Rd', 10820: 'Veterans Hospital West Roxbury', 10821: 'Charles Park Rd @ VFW Pkwy', 1083: 'Market St @ Arlington St', 10830: '17 Charles Park Rd', 10833: 'Dedham Mall @ Stop & Shop', 10835: 'Dedham Mall @ South Side', 1084: 'Chestnut Hill Ave @ Washington St', 1085: 'Chestnut Hill Ave @ Academy Hill Rd', 1086: 'Chestnut Hill Ave @ Jackson Ave', 1088: 'Chestnut Hill Ave @ Embassy Rd', 1089: 'Chestnut Hill Ave @ South St', 109: 'Massachusetts Ave @ Bow St', 1090: 'Chestnut Hill Ave @ Commonwealth Ave', 1092: 'Chestnut Hill Ave @ Beacon St', 10923: 'Cummins Hwy @ Wood Ave', 10928: 'Harvard Ave @ Brighton Ave', 1094: 'Brooks St @ Faneuil St', 109802: 'Saratoga St @ Teragram St', 109804: 'Main St @ Pleasan ...
# {1: nan, 10: nan, 10000: nan, 10003: nan, 10005: nan, 10006: nan, 10007: nan, 10008: nan, 10009: nan, 10010: nan, 10011: nan, 10012: nan, 10013: nan, 10014: nan, 10015: nan, 10016: nan, 10031: nan, 10032: nan, 10033: nan, 101: nan, 10100: nan, 10101: nan, 102: nan, 1026: nan, 1027: nan, 1029: nan, 1030: nan, 1032: nan, 1033: nan, 1034: nan, 1035: nan, 1036: nan, 1038: nan, 1039: nan, 104: nan, 1040: nan, 1041: nan, 10413: nan, 10417: nan, 10418: nan, 10419: nan, 1042: nan, 10421: nan, 10422: nan, 10423: nan, 10424: nan, 10425: nan, 10427: nan, 1043: nan, 1045: nan, 1046: nan, 1049: nan, 1051: nan, 1052: nan, 10522: nan, 1053: nan, 10540: nan, 1055: nan, 1056: nan, 10569: nan, 1057: nan, 1058: nan, 10582: nan, 1059: nan, 10590: nan, 106: nan, 1060: nan, 10603: nan, 1061: nan, 10612: nan, 10618: nan, 1062: nan, 10625: nan, 10633: nan, 1064: nan, 1067: nan, 1068: nan, 107: nan, 1070: nan, 1071: nan, 1072: nan, 1074: nan, 1075: nan, 1076: nan, 10768: nan, 10769: nan, 1077: nan, 10777: nan, 1079: nan, 108: nan, 1080: nan, 1081: nan, 10820: nan, 10821: nan, 1083: nan, 10830: nan, 10833: nan, 10835: nan, 1084: nan, 1085: nan, 1086: nan, 1088: nan, 1089: nan, 109: nan, 1090: nan, 1092: nan, 10923: nan, 10928: nan, 1094: nan, 109802: nan, 109804: nan, 109805: nan, 109806: nan, 109808: nan, 109809: nan, 109810: nan, 109811: nan, 109812: nan, 109814: nan, 109815: nan, 109816: nan, 109817: nan, 109818: nan, 109819: nan, 109820: nan, 109821: nan, 109822: nan, 109823: nan, 109824: nan, 109825: nan, 109826: nan, 109827: nan, 109828: nan, 109829: nan, 109830: nan, 109831: nan, 109832: nan, 109835: nan, 109836: nan, 109838: nan, 109841: nan, 109842: nan, 109844: nan, 109845: nan, 109846: nan, 109848: nan, 109849: nan, 109853: nan, 109857: nan, 109858: nan, 109860: nan, 109861: nan, 109862: nan, 109864: nan, 109865: nan, 109870: nan, 109871: nan, 109872: nan, 109873: nan, 109874: nan, 109875: nan, 109877: nan, 109878: nan, 109879: nan, 109880: nan, 109883: nan, 109884: nan, 109885: nan, 109886: nan, 109887: nan, 109888: nan, 109890: nan, 109891: nan, 109892: nan, 109893: nan, 109894: nan, 109896: nan, 109898: nan, 109899: nan, 109900: nan, 109901: nan, 109912: nan, 11: nan, 110: nan, 1100: nan, 1102: nan, 1103: nan, 1104: nan, 1105: nan, 11070: nan, 11071: nan, 111: nan, 1110: nan, 1111: nan, 111146: nan, 111152: nan, 111159: nan, 111179: nan, 111196: nan, 1112: nan, 111206: nan, 111214: nan, 111217: nan, 111232: nan, 111234: nan, 111236: nan, 111248: nan, 111251: nan, 111258: nan, 11131: nan, 1114: nan, 11148: nan, 11149: nan, 1115: nan, 11158: nan, 1116: nan, 11164: nan, 111640: nan, 111642: nan, 111648: nan, 111653: nan, 111656: nan, 111660: nan, 111672: nan, 111685: nan, 111711: nan, 111720: nan, 111729: nan, 111738: nan, 111747: nan, 111762: nan, 111775: nan, 111787: nan, 111791: nan, 111796: nan, 111801: nan, 111803: nan, 111806: nan, 111810: nan, 111815: nan, 111823: nan, 111828: nan, 111830: nan, 111844: nan, 111848: nan, 111855: nan, 111864: nan, 11187: nan, 111881: nan, 111895: nan, 111907: nan, 11219: nan, 11228: nan, 1123: nan, 11241: nan, 11242: nan, 11244: nan, 11257: nan, 11259: nan, 1128: nan, 1129: nan, 113: nan, 1130: nan, 11302: nan, 11319: nan, 1132: nan, 11323: nan, 1134: nan, 1135: nan, 1136: nan, 11366: nan, 1137: nan, 1138: nan, 11384: nan, 11388: nan, 11389: nan, 11390: nan, 11391: nan, 114: nan, 1140: nan, 11408: nan, 1141: nan, 11410: nan, 11413: nan, 11419: nan, 1142: nan, 1144: nan, 1145: nan, 1147: nan, 1148: nan, 11481: nan, 11482: nan, 114878: nan, 114882: nan, 1149: nan, 1150: nan, 11501: nan, 1151: nan, 11512: nan, 1152: nan, 11521: nan, 11522: nan, 1153: nan, 1154: nan, 11545: nan, 1155: nan, 1156: nan, 1158: nan, 11587: nan, 1159: nan, 11592: nan, 11593: nan, 11599: nan, 1160: nan, 1161: nan, 11613: nan, 11618: nan, 1164: nan, 1165: nan, 1166: nan, 1167: nan, 1168: nan, 11689: nan, 1169: nan, 11694: nan, 117: nan, 1170: nan, 11712: nan, 11719: nan, 1172: nan, 1173: nan, 11735: nan, 11736: nan, 1174: nan, 1175 ...

# %% [markdown]
# Check for stop_ids that are not in stops.csv

# %%
unassigned_stops = []
for i in dfs:
    df = dfs[i]
    # Create the 'stop_name' column by mapping 'stop_id' using the stop_id_to_name dictionary
    df['stop_name'] = df['stop_id'].map(stop_dict)
    df['stop_desc'] = df['stop_id'].map(stop_desc_dict)
    print(df.head())
    # Filter rows where 'stop_name' is blank (either NaN or empty string)
    blank_stop_names = df[df['stop_name'].isna() | (df['stop_name'] == '')]

    # Get unique stop_ids from those rows
    unassigned_stops.extend(blank_stop_names['stop_id'].tolist())

# Print the unique stop_ids
unique_unassigned_stops = list(set(unassigned_stops))
print(unique_unassigned_stops)
# Out:
#    stop_id  direction_id   destination  headway_time_sec     stop_name  \
# 0    70001             1     Oak Grove        499.692239  Forest Hills
# 1    70002             0  Forest Hills        509.656499  Green Street
# 2    70003             1     Oak Grove        512.070998  Green Street
# 3    70004             0  Forest Hills        506.538108   Stony Brook
# 4    70005             1     Oak Grove        512.941418   Stony Brook
#
#                                    stop_desc
# 0                 Forest Hills - Orange Line
# 1  Green Street - Orange Line - Forest Hills
# 2     Green Street - Orange Line - Oak Grove
# 3   Stony Brook - Orange Line - Forest Hills
# 4      Stony Brook - Orange Line - Oak Grove
#    stop_id  direction_id   destination  headway_time_sec     stop_name  \
# 0    70001             1     Oak Grove        505.786136  Forest Hills
# 1    70002             0  Forest Hills        505.573351  Green Street
# 2    70003             1     Oak Grove        507.114465  Green Street
# 3    70004             0  Forest Hills        505.320893   Stony Brook
# 4    70005             1     Oak Grove        509.227303   Stony Brook
#
#                                    stop_desc
# 0                 Forest Hills - Orange Line
# 1  Green Street - Orange Line - Forest Hills
# 2     Green Street - Orange Line - Oak Grove
# 3   Stony Brook - Orange Line - Forest Hills
# 4      Stony Brook - Orange Line - Oak Grove
#    stop_id  direction_id   destination  headway_time_sec     stop_name  \
# 0    70001             0  Forest Hills       1056.137931  Forest Hills
# 1    70001             1     Oak Grove        512.213911  Forest Hills
# 2    70002             0  Forest Hills        519.718360  Green Street
# 3    70003             1     Oak Grove        514.117837  Green Street
# 4    70004             0  Forest Hills        519.019428   Stony Brook
#
#                                    stop_desc
# 0                 Forest Hills - Orange Line
# 1                 Forest Hills - Orange Line
# 2  Green Street - Orange Line - Forest Hills
# 3     Green Street - Orange Line - Oak Grove
# 4   Stony Brook - Orange Line - Forest Hills
#    stop_id  direction_id   destination  headway_time_sec     stop_name  \
# 0    70001             0  Forest Hills        684.672269  Forest Hills
# 1    70001             1     Oak Grove        519.148623  Forest Hills
# 2    70002             0  Forest Hills        521.140717  Green Street
# 3    70003             1     Oak Grove        512.021927  Green Street
# 4    70004             0  Forest Hills        521.435207   Stony Brook
#
#                                    stop_desc
# 0                 Forest Hills - Orange Line
# 1                 Forest Hills - Orange Line
# 2  Green Street - Orange Line - Forest Hills
# 3     Green Street - Orange Line - Oak Grove
# 4   Stony Brook - Orange Line - Forest Hills
#    stop_id  direction_id   destination  headway_time_sec     stop_name  \
# 0    70001             0  Forest Hills        560.257447  Forest Hills
# 1    70001             1     Oak Grove        538.074998  Forest Hills
# 2    70002             0  Forest Hills        539.821318  Green Street
# 3    70003             1     Oak Grove        531.558340  Green Street
# 4    70004             0  Forest Hills        540.200726   Stony Brook
#
#                                    stop_desc
# 0                 Forest Hills - Orange Line
# 1                 Forest Hills - Orange Line
# 2  Green Street - Orange Line - Forest Hills
# 3     Green Street - Orange Line - Oak Grove
# 4   Stony Brook - Orange Line - Forest Hills
#    stop_id  direction_id   destination  headway_time_sec     stop_name  \
# 0    70001             0  Forest Hills        532.000000  Forest Hills
# 1    70001             1     Oak Grove        568.392724  Forest Hills
# 2    70002             0  Forest Hills        569.730113  Green Street
# 3    70003             1     Oak Grove        563.100133  Green Street
# 4    70004             0  Forest Hills        570.394914   Stony Brook
#
#                                    stop_desc
# 0                 Forest Hills - Orange Line
# 1                 Forest Hills - Orange Line
# 2  Green Street - Orange Line - Forest Hills
# 3     Green Street - Orange Line - Oak Grove
# 4   Stony Brook - Orange Line - Forest Hills
#    stop_id  direction_id   destination  headway_time_sec     stop_name  \
# 0    70001             0  Forest Hills        547.000000  Forest Hills
# 1    70001             1     Oak Grove        593.277430  Forest Hills
# 2    70002             0  Forest Hills        589.646489  Green Street
# 3    70003             1     Oak Grove        588.729268  Green Street
# 4    70004             0  Forest Hills        590.257927   Stony Brook
#
#                                    stop_desc
# 0                 Forest Hills - Orange Line
# 1                 Forest Hills - Orange Line
# 2  Green Street - Orange Line - Forest Hills
# 3     Green Street - Orange Line - Oak Grove
# 4   Stony Brook - Orange Line - Forest Hills
# [70209, 70210, 70262, 70136, 70137, 70138, 70139, 70140, 70141, 70142, 70143]

# %% [markdown]
# Check that all MBTA stops are included in the datasets

# %%
red_line = ['Alewife', 'Davis', 'Porter', 'Harvard', 'Central', 'Kendall/MIT', 'Charles/MGH', 'Park Street', 'Downtown Crossing', 'South Station', 'Broadway', 'Andrew', 'JFK/UMass', 'Savin Hill', 'Fields Corner', 'Shawmut', 'Ashmont', 'Cedar Grove', 'Butler', 'Milton', 'Central Avenue', 'Valley Road', 'Capen Street', 'Mattapan', 'North Quincy', 'Wollaston', 'Quincy Center', 'Quincy Adams', 'Braintree']
green_line = ['Medford/Tufts', 'Ball Square', 'Magoun Square', 'Gilman Square', 'East Somerville', 'Union Square', 'Lechmere', 'Science Park/West End', 'North Station', 'Haymarket', 'Government Center', 'Park Street', 'Boylston', 'Arlington', 'Copley', 'Hynes Convention Center', 'Kenmore', 'Blandford Street', 'Boston University East', 'Boston University Central', 'Amory Street', 'Babcock Street', 'Packard\'s Corner', 'Harvard Avenue', 'Griggs Street', 'Allston Street', 'Warren Street', 'Washington Street', 'Sutherland Road', 'Chiswick Road', 'Chestnut Hill Avenue', 'South Street', 'Boston College', "Saint Mary's Street", 'Hawes Street', 'Kent Street', 'Saint Paul Street', 'Coolidge Corner', 'Summit Avenue', 'Brandon Hall', 'Fairbanks Street', 'Washington Square', 'Tappan Street', 'Dean Road', 'Englewood Avenue', 'Cleveland Circle', 'Fenway', 'Longwood', 'Brookline Village', 'Brookline Hills', 'Beaconsfield', 'Reservoir', 'Chestnut Hill', 'Newton Centre', 'Newton Highlands', 'Eliot', 'Waban', 'Woodland', 'Riverside', 'Prudential', 'Symphony', 'Northeastern University', 'Museum of Fine Arts', 'Longwood Medical Area', 'Brigham Circle', 'Fenwood Road', 'Mission Park', 'Riverway', 'Back of the Hill', 'Heath Street']
blue_line = ['Bowdoin', 'Government Center', 'State', 'Aquarium', 'Maverick', 'Airport', 'Wood Island', 'Orient Heights', 'Suffolk Downs', 'Beachmont', 'Revere Beach', 'Wonderland']
orange_line = ['Oak Grove', 'Malden Center', 'Wellington', 'Assembly', 'Sullivan Square', 'Community College', 'North Station', 'Haymarket', 'State', 'Downtown Crossing', 'Chinatown', 'Tufts Medical Center', 'Back Bay', 'Massachusetts Avenue', 'Ruggles', 'Roxbury Crossing', 'Jackson Square', 'Stony Brook', 'Green Street', 'Forest Hills']

# %%
for i in dfs:
    df = dfs[i]
    print(f"Unique stops in the {i} data: {df['stop_name'].unique()}")
    print()
# Out:
# Unique stops in the 2016 data: ['Forest Hills' 'Green Street' 'Stony Brook' 'Jackson Square'
#  'Roxbury Crossing' 'Ruggles' 'Massachusetts Avenue' 'Back Bay'
#  'Tufts Medical Center' 'Chinatown' 'Downtown Crossing' 'State'
#  'Haymarket' 'North Station' 'Community College' 'Sullivan Square'
#  'Wellington' 'Malden Center' 'Oak Grove' 'Bowdoin' 'Government Center'
#  'Aquarium' 'Maverick' 'Airport' 'Wood Island' 'Orient Heights'
#  'Suffolk Downs' 'Beachmont' 'Revere Beach' 'Wonderland' 'Alewife' 'Davis'
#  'Porter' 'Harvard' 'Central' 'Kendall/MIT' 'Charles/MGH' 'Park Street'
#  'South Station' 'Broadway' 'Andrew' 'JFK/UMass' 'Savin Hill'
#  'Fields Corner' 'Shawmut' 'Ashmont' 'North Quincy' 'Wollaston'
#  'Quincy Center' 'Quincy Adams' 'Braintree' 'Boston College'
#  'South Street' 'Chestnut Hill Avenue' 'Chiswick Road' 'Sutherland Road'
#  'Washington Street' 'Warren Street' 'Allston Street' 'Griggs Street'
#  'Harvard Avenue' "Packard's Corner" nan 'Boston University Central'
#  'Boston University East' 'Blandford Street' 'Kenmore'
#  'Hynes Convention Center' 'Copley' 'Arlington' 'Boylston' 'Riverside'
#  'Woodland' 'Waban' 'Eliot' 'Newton Highlands' 'Newton Centre'
#  'Chestnut Hill' 'Reservoir' 'Beaconsfield' 'Brookline Hills'
#  'Brookline Village' 'Longwood' 'Fenway' 'Science Park/West End'
#  "Saint Mary's Street" 'Hawes Street' 'Kent Street' 'Saint Paul Street'
#  'Coolidge Corner' 'Summit Avenue' 'Brandon Hall' 'Fairbanks Street'
#  'Washington Square' 'Tappan Street' 'Dean Road' 'Englewood Avenue'
#  'Cleveland Circle' 'Prudential' 'Symphony' 'Northeastern University'
#  'Museum of Fine Arts' 'Longwood Medical Area' 'Brigham Circle'
#  'Fenwood Road' 'Mission Park' 'Riverway' 'Back of the Hill'
#  'Heath Street' 'Assembly']
#
# Unique stops in the 2017 data: ['Forest Hills' 'Green Street' 'Stony Brook' 'Jackson Square'
#  'Roxbury Crossing' 'Ruggles' 'Massachusetts Avenue' 'Back Bay'
#  'Tufts Medical Center' 'Chinatown' 'Downtown Crossing' 'State'
#  'Haymarket' 'North Station' 'Community College' 'Sullivan Square'
#  'Wellington' 'Malden Center' 'Oak Grove' 'Bowdoin' 'Government Center'
#  'Aquarium' 'Maverick' 'Airport' 'Wood Island' 'Orient Heights'
#  'Suffolk Downs' 'Beachmont' 'Revere Beach' 'Wonderland' 'Alewife' 'Davis'
#  'Porter' 'Harvard' 'Central' 'Kendall/MIT' 'Charles/MGH' 'Park Street'
#  'South Station' 'Broadway' 'Andrew' 'JFK/UMass' 'Savin Hill'
#  'Fields Corner' 'Shawmut' 'Ashmont' 'North Quincy' 'Wollaston'
#  'Quincy Center' 'Quincy Adams' 'Braintree' 'Boston College'
#  'South Street' 'Chestnut Hill Avenue' 'Chiswick Road' 'Sutherland Road'
#  'Washington Street' 'Warren Street' 'Allston Street' 'Griggs Street'
#  'Harvard Avenue' "Packard's Corner" nan 'Boston University Central'
#  'Boston University East' 'Blandford Street' 'Kenmore'
#  'Hynes Convention Center' 'Copley' 'Arlington' 'Boylston' 'Riverside'
#  'Woodland' 'Waban' 'Eliot' 'Newton Highlands' 'Newton Centre'
#  'Chestnut Hill' 'Reservoir' 'Beaconsfield' 'Brookline Hills'
#  'Brookline Village' 'Longwood' 'Fenway' 'Science Park/West End'
#  "Saint Mary's Street" 'Hawes Street' 'Kent Street' 'Saint Paul Street'
#  'Coolidge Corner' 'Summit Avenue' 'Brandon Hall' 'Fairbanks Street'
#  'Washington Square' 'Tappan Street' 'Dean Road' 'Englewood Avenue'
#  'Cleveland Circle' 'Prudential' 'Symphony' 'Northeastern University'
#  'Museum of Fine Arts' 'Longwood Medical Area' 'Brigham Circle'
#  'Fenwood Road' 'Mission Park' 'Riverway' 'Back of the Hill'
#  'Heath Street' 'Cedar Grove' 'Butler' 'Milton' 'Central Avenue'
#  'Valley Road' 'Capen Street' 'Assembly']
#
# Unique stops in the 2018 data: ['Forest Hills' 'Green Street' 'Stony Brook' 'Jackson Square'
#  'Roxbury Crossing' 'Ruggles' 'Massachusetts Avenue' 'Back Bay'
#  'Tufts Medical Center' 'Chinatown' 'Downtown Crossing' 'State'
#  'Haymarket' 'North Station' 'Community College' 'Sullivan Square'
#  'Wellington' 'Malden Center' 'Oak Grove' 'Bowdoin' 'Government Center'
#  'Aquarium' 'Maverick' 'Airport' 'Wood Island' 'Orient Heights'
#  'Suffolk Downs' 'Beachmont' 'Revere Beach' 'Wonderland' 'Alewife' 'Davis'
#  'Porter' 'Harvard' 'Central' 'Kendall/MIT' 'Charles/MGH' 'Park Street'
#  'South Station' 'Broadway' 'Andrew' 'JFK/UMass' 'Savin Hill'
#  'Fields Corner' 'Shawmut' 'Ashmont' 'North Quincy' 'Wollaston'
#  'Quincy Center' 'Quincy Adams' 'Braintree' 'Boston College'
#  'South Street' 'Chestnut Hill Avenue' 'Chiswick Road' 'Sutherland Road'
#  'Washington Street' 'Warren Street' 'Allston Street' 'Griggs Street'
#  'Harvard Avenue' "Packard's Corner" nan 'Boston University Central'
#  'Boston University East' 'Blandford Street' 'Kenmore'
#  'Hynes Convention Center' 'Copley' 'Arlington' 'Boylston' 'Riverside'
#  'Woodland' 'Waban' 'Eliot' 'Newton Highlands' 'Newton Centre'
#  'Chestnut Hill' 'Reservoir' 'Beaconsfield' 'Brookline Hills'
#  'Brookline Village' 'Longwood' 'Fenway' 'Science Park/West End'
#  "Saint Mary's Street" 'Hawes Street' 'Kent Street' 'Saint Paul Street'
#  'Coolidge Corner' 'Summit Avenue' 'Brandon Hall' 'Fairbanks Street'
#  'Washington Square' 'Tappan Street' 'Dean Road' 'Englewood Avenue'
#  'Cleveland Circle' 'Prudential' 'Symphony' 'Northeastern University'
#  'Museum of Fine Arts' 'Longwood Medical Area' 'Brigham Circle'
#  'Fenwood Road' 'Mission Park' 'Riverway' 'Back of the Hill'
#  'Heath Street' 'Cedar Grove' 'Butler' 'Milton' 'Central Avenue'
#  'Valley Road' 'Capen Street' 'Mattapan' 'Assembly']
#
# Unique stops in the 2019 data: ['Forest Hills' 'Green Street' 'Stony Brook' 'Jackson Square'
#  'Roxbury Crossing' 'Ruggles' 'Massachusetts Avenue' 'Back Bay'
#  'Tufts Medical Center' 'Chinatown' 'Downtown Crossing' 'State'
#  'Haymarket' 'North Station' 'Community College' 'Sullivan Square'
#  'Wellington' 'Malden Center' 'Oak Grove' 'Bowdoin' 'Government Center'
#  'Aquarium' 'Maverick' 'Airport' 'Wood Island' 'Orient Heights'
#  'Suffolk Downs' 'Beachmont' 'Revere Beach' 'Wonderland' 'Alewife' 'Davis'
#  'Porter' 'Harvard' 'Central' 'Kendall/MIT' 'Charles/MGH' 'Park Street'
#  'South Station' 'Broadway' 'Andrew' 'JFK/UMass' 'Savin Hill'
#  'Fields Corner' 'Shawmut' 'Ashmont' 'North Quincy' 'Wollaston'
#  'Quincy Center' 'Quincy Adams' 'Braintree' 'Boston College'
#  'South Street' 'Chestnut Hill Avenue' 'Chiswick Road' 'Sutherland Road'
#  'Washington Street' 'Warren Street' 'Allston Street' 'Griggs Street'
#  'Harvard Avenue' "Packard's Corner" nan 'Boston University Central'
#  'Boston University East' 'Blandford Street' 'Kenmore'
#  'Hynes Convention Center' 'Copley' 'Arlington' 'Boylston' 'Riverside'
#  'Woodland' 'Waban' 'Eliot' 'Newton Highlands' 'Newton Centre'
#  'Chestnut Hill' 'Reservoir' 'Beaconsfield' 'Brookline Hills'
#  'Brookline Village' 'Longwood' 'Fenway' 'Science Park/West End'
#  "Saint Mary's Street" 'Hawes Street' 'Kent Street' 'Saint Paul Street'
#  'Coolidge Corner' 'Summit Avenue' 'Brandon Hall' 'Fairbanks Street'
#  'Washington Square' 'Tappan Street' 'Dean Road' 'Englewood Avenue'
#  'Cleveland Circle' 'Prudential' 'Symphony' 'Northeastern University'
#  'Museum of Fine Arts' 'Longwood Medical Area' 'Brigham Circle'
#  'Fenwood Road' 'Mission Park' 'Riverway' 'Back of the Hill'
#  'Heath Street' 'Cedar Grove' 'Butler' 'Milton' 'Central Avenue'
#  'Valley Road' 'Capen Street' 'Mattapan' 'Assembly']
#
# Unique stops in the 2020 data: ['Forest Hills' 'Green Street' 'Stony Brook' 'Jackson Square'
#  'Roxbury Crossing' 'Ruggles' 'Massachusetts Avenue' 'Back Bay'
#  'Tufts Medical Center' 'Chinatown' 'Downtown Crossing' 'State'
#  'Haymarket' 'North Station' 'Community College' 'Sullivan Square'
#  'Wellington' 'Malden Center' 'Oak Grove' 'Bowdoin' 'Government Center'
#  'Aquarium' 'Maverick' 'Airport' 'Wood Island' 'Orient Heights'
#  'Suffolk Downs' 'Beachmont' 'Revere Beach' 'Wonderland' 'Alewife' 'Davis'
#  'Porter' 'Harvard' 'Central' 'Kendall/MIT' 'Charles/MGH' 'Park Street'
#  'South Station' 'Broadway' 'Andrew' 'JFK/UMass' 'Savin Hill'
#  'Fields Corner' 'Shawmut' 'Ashmont' 'North Quincy' 'Wollaston'
#  'Quincy Center' 'Quincy Adams' 'Braintree' 'Boston College'
#  'South Street' 'Chestnut Hill Avenue' 'Chiswick Road' 'Sutherland Road'
#  'Washington Street' 'Warren Street' 'Allston Street' 'Griggs Street'
#  'Harvard Avenue' "Packard's Corner" nan 'Boston University Central'
#  'Boston University East' 'Blandford Street' 'Kenmore'
#  'Hynes Convention Center' 'Copley' 'Arlington' 'Boylston' 'Riverside'
#  'Woodland' 'Waban' 'Eliot' 'Newton Highlands' 'Newton Centre'
#  'Chestnut Hill' 'Reservoir' 'Beaconsfield' 'Brookline Hills'
#  'Brookline Village' 'Longwood' 'Fenway' 'Science Park/West End'
#  "Saint Mary's Street" 'Hawes Street' 'Kent Street' 'Saint Paul Street'
#  'Coolidge Corner' 'Summit Avenue' 'Brandon Hall' 'Fairbanks Street'
#  'Washington Square' 'Tappan Street' 'Dean Road' 'Englewood Avenue'
#  'Prudential' 'Symphony' 'Northeastern University' 'Museum of Fine Arts'
#  'Longwood Medical Area' 'Brigham Circle' 'Fenwood Road' 'Mission Park'
#  'Riverway' 'Back of the Hill' 'Heath Street' 'Cedar Grove' 'Butler'
#  'Milton' 'Central Avenue' 'Valley Road' 'Capen Street' 'Mattapan'
#  'Assembly']
#
# Unique stops in the 2021 data: ['Forest Hills' 'Green Street' 'Stony Brook' 'Jackson Square'
#  'Roxbury Crossing' 'Ruggles' 'Massachusetts Avenue' 'Back Bay'
#  'Tufts Medical Center' 'Chinatown' 'Downtown Crossing' 'State'
#  'Haymarket' 'North Station' 'Community College' 'Sullivan Square'
#  'Wellington' 'Malden Center' 'Oak Grove' 'Bowdoin' 'Government Center'
#  'Aquarium' 'Maverick' 'Airport' 'Wood Island' 'Orient Heights'
#  'Suffolk Downs' 'Beachmont' 'Revere Beach' 'Wonderland' 'Alewife' 'Davis'
#  'Porter' 'Harvard' 'Central' 'Kendall/MIT' 'Charles/MGH' 'Park Street'
#  'South Station' 'Broadway' 'Andrew' 'JFK/UMass' 'Savin Hill'
#  'Fields Corner' 'Shawmut' 'Ashmont' 'North Quincy' 'Wollaston'
#  'Quincy Center' 'Quincy Adams' 'Braintree' 'Boston College'
#  'South Street' 'Chestnut Hill Avenue' 'Chiswick Road' 'Sutherland Road'
#  'Washington Street' 'Warren Street' 'Allston Street' 'Griggs Street'
#  'Harvard Avenue' "Packard's Corner" nan 'Boston University Central'
#  'Boston University East' 'Blandford Street' 'Kenmore'
#  'Hynes Convention Center' 'Copley' 'Arlington' 'Boylston' 'Riverside'
#  'Woodland' 'Waban' 'Eliot' 'Newton Highlands' 'Newton Centre'
#  'Chestnut Hill' 'Reservoir' 'Beaconsfield' 'Brookline Hills'
#  'Brookline Village' 'Longwood' 'Fenway' "Saint Mary's Street"
#  'Hawes Street' 'Kent Street' 'Saint Paul Street' 'Coolidge Corner'
#  'Summit Avenue' 'Brandon Hall' 'Fairbanks Street' 'Washington Square'
#  'Tappan Street' 'Dean Road' 'Englewood Avenue' 'Prudential' 'Symphony'
#  'Northeastern University' 'Museum of Fine Arts' 'Longwood Medical Area'
#  'Brigham Circle' 'Fenwood Road' 'Mission Park' 'Riverway'
#  'Back of the Hill' 'Heath Street' 'Cedar Grove' 'Butler' 'Milton'
#  'Central Avenue' 'Valley Road' 'Capen Street' 'Mattapan' 'Assembly'
#  'Babcock Street' 'Amory Street']
#
# Unique stops in the 2022 data: ['Forest Hills' 'Green Street' 'Stony Brook' 'Jackson Square'
#  'Roxbury Crossing' 'Ruggles' 'Massachusetts Avenue' 'Back Bay'
#  'Tufts Medical Center' 'Chinatown' 'Downtown Crossing' 'State'
#  'Haymarket' 'North Station' 'Community College' 'Sullivan Square'
#  'Wellington' 'Malden Center' 'Oak Grove' 'Bowdoin' 'Government Center'
#  'Aquarium' 'Maverick' 'Airport' 'Wood Island' 'Orient Heights'
#  'Suffolk Downs' 'Beachmont' 'Revere Beach' 'Wonderland' 'Alewife' 'Davis'
#  'Porter' 'Harvard' 'Central' 'Kendall/MIT' 'Charles/MGH' 'Park Street'
#  'South Station' 'Broadway' 'Andrew' 'JFK/UMass' 'Savin Hill'
#  'Fields Corner' 'Shawmut' 'Ashmont' 'North Quincy' 'Wollaston'
#  'Quincy Center' 'Quincy Adams' 'Braintree' 'Boston College'
#  'South Street' 'Chestnut Hill Avenue' 'Chiswick Road' 'Sutherland Road'
#  'Washington Street' 'Warren Street' 'Allston Street' 'Griggs Street'
#  'Harvard Avenue' "Packard's Corner" 'Boston University Central'
#  'Boston University East' 'Blandford Street' 'Kenmore'
#  'Hynes Convention Center' 'Copley' 'Arlington' 'Boylston' 'Riverside'
#  'Woodland' 'Waban' 'Eliot' 'Newton Highlands' 'Newton Centre'
#  'Chestnut Hill' 'Reservoir' 'Beaconsfield' 'Brookline Hills'
#  'Brookline Village' 'Longwood' 'Fenway' 'Science Park/West End'
#  "Saint Mary's Street" 'Hawes Street' 'Kent Street' 'Saint Paul Street'
#  'Coolidge Corner' 'Summit Avenue' 'Brandon Hall' 'Fairbanks Street'
#  'Washington Square' 'Tappan Street' 'Dean Road' 'Englewood Avenue'
#  'Cleveland Circle' 'Prudential' 'Symphony' 'Northeastern University'
#  'Museum of Fine Arts' 'Longwood Medical Area' 'Brigham Circle'
#  'Fenwood Road' 'Mission Park' 'Riverway' 'Back of the Hill'
#  'Heath Street' 'Cedar Grove' 'Butler' 'Milton' 'Central Avenue'
#  'Valley Road' 'Capen Street' 'Mattapan' 'Assembly' 'Lechmere'
#  'Gilman Square' 'Magoun Square' 'Ball Square' 'Medford/Tufts'
#  'East Somerville' 'Babcock Street' 'Amory Street']

# %%
for i in dfs:
    df = dfs[i]
    red_missing = [stop for stop in red_line if stop not in df['stop_name'].values]
    green_missing = [stop for stop in green_line if stop not in df['stop_name'].values]
    blue_missing = [stop for stop in blue_line if stop not in df['stop_name'].values]
    orange_missing = [stop for stop in orange_line if stop not in df['stop_name'].values]
    print(f"{i} Data")
    print("Red Line Missing Stops:", red_missing)
    print("Green Line Missing Stops:", green_missing)
    print("Blue Line Missing Stops:", blue_missing)
    print("Orange Line Missing Stops:", orange_missing)
    
    not_in_lines = df[~df['stop_name'].isin(red_line + green_line + blue_line + orange_line)]['stop_name'].unique()

    print("Stops not in any line arrays:", not_in_lines)
# Out:
# 2016 Data
# Red Line Missing Stops: ['Cedar Grove', 'Butler', 'Milton', 'Central Avenue', 'Valley Road', 'Capen Street', 'Mattapan']
# Green Line Missing Stops: ['Medford/Tufts', 'Ball Square', 'Magoun Square', 'Gilman Square', 'East Somerville', 'Union Square', 'Lechmere', 'Amory Street', 'Babcock Street']
# Blue Line Missing Stops: []
# Orange Line Missing Stops: []
# Stops not in any line arrays: [nan]
# 2017 Data
# Red Line Missing Stops: ['Mattapan']
# Green Line Missing Stops: ['Medford/Tufts', 'Ball Square', 'Magoun Square', 'Gilman Square', 'East Somerville', 'Union Square', 'Lechmere', 'Amory Street', 'Babcock Street']
# Blue Line Missing Stops: []
# Orange Line Missing Stops: []
# Stops not in any line arrays: [nan]
# 2018 Data
# Red Line Missing Stops: []
# Green Line Missing Stops: ['Medford/Tufts', 'Ball Square', 'Magoun Square', 'Gilman Square', 'East Somerville', 'Union Square', 'Lechmere', 'Amory Street', 'Babcock Street']
# Blue Line Missing Stops: []
# Orange Line Missing Stops: []
# Stops not in any line arrays: [nan]
# 2019 Data
# Red Line Missing Stops: []
# Green Line Missing Stops: ['Medford/Tufts', 'Ball Square', 'Magoun Square', 'Gilman Square', 'East Somerville', 'Union Square', 'Lechmere', 'Amory Street', 'Babcock Street']
# Blue Line Missing Stops: []
# Orange Line Missing Stops: []
# Stops not in any line arrays: [nan]
# 2020 Data
# Red Line Missing Stops: []
# Green Line Missing Stops: ['Medford/Tufts', 'Ball Square', 'Magoun Square', 'Gilman Square', 'East Somerville', 'Union Square', 'Lechmere', 'Amory Street', 'Babcock Street', 'Cleveland Circle']
# Blue Line Missing Stops: []
# Orange Line Missing Stops: []
# Stops not in any line arrays: [nan]
# 2021 Data
# Red Line Missing Stops: []
# Green Line Missing Stops: ['Medford/Tufts', 'Ball Square', 'Magoun Square', 'Gilman Square', 'East Somerville', 'Union Square', 'Lechmere', 'Science Park/West End', 'Cleveland Circle']
# Blue Line Missing Stops: []
# Orange Line Missing Stops: []
# Stops not in any line arrays: [nan]
# 2022 Data
# Red Line Missing Stops: []
# Green Line Missing Stops: ['Union Square']
# Blue Line Missing Stops: []
# Orange Line Missing Stops: []
# Stops not in any line arrays: []

# %% [markdown]
# Add a train line column to each row

# %%
def assign_line_dest(destination):
   if destination in red_line:
       return 'red'
   elif destination in green_line:
       return 'green'
   elif destination in blue_line:
       return 'blue'
   elif destination in orange_line:
       return 'orange'
   else:
       return 'unknown'

for i in dfs:
    df = dfs[i]
    df['line'] = df['destination'].apply(assign_line_dest)
    print(df.head())
# Out:
#    stop_id  direction_id   destination  headway_time_sec     stop_name  \
# 0    70001             1     Oak Grove        499.692239  Forest Hills
# 1    70002             0  Forest Hills        509.656499  Green Street
# 2    70003             1     Oak Grove        512.070998  Green Street
# 3    70004             0  Forest Hills        506.538108   Stony Brook
# 4    70005             1     Oak Grove        512.941418   Stony Brook
#
#                                    stop_desc    line
# 0                 Forest Hills - Orange Line  orange
# 1  Green Street - Orange Line - Forest Hills  orange
# 2     Green Street - Orange Line - Oak Grove  orange
# 3   Stony Brook - Orange Line - Forest Hills  orange
# 4      Stony Brook - Orange Line - Oak Grove  orange
#    stop_id  direction_id   destination  headway_time_sec     stop_name  \
# 0    70001             1     Oak Grove        505.786136  Forest Hills
# 1    70002             0  Forest Hills        505.573351  Green Street
# 2    70003             1     Oak Grove        507.114465  Green Street
# 3    70004             0  Forest Hills        505.320893   Stony Brook
# 4    70005             1     Oak Grove        509.227303   Stony Brook
#
#                                    stop_desc    line
# 0                 Forest Hills - Orange Line  orange
# 1  Green Street - Orange Line - Forest Hills  orange
# 2     Green Street - Orange Line - Oak Grove  orange
# 3   Stony Brook - Orange Line - Forest Hills  orange
# 4      Stony Brook - Orange Line - Oak Grove  orange
#    stop_id  direction_id   destination  headway_time_sec     stop_name  \
# 0    70001             0  Forest Hills       1056.137931  Forest Hills
# 1    70001             1     Oak Grove        512.213911  Forest Hills
# 2    70002             0  Forest Hills        519.718360  Green Street
# 3    70003             1     Oak Grove        514.117837  Green Street
# 4    70004             0  Forest Hills        519.019428   Stony Brook
#
#                                    stop_desc    line
# 0                 Forest Hills - Orange Line  orange
# 1                 Forest Hills - Orange Line  orange
# 2  Green Street - Orange Line - Forest Hills  orange
# 3     Green Street - Orange Line - Oak Grove  orange
# 4   Stony Brook - Orange Line - Forest Hills  orange
#    stop_id  direction_id   destination  headway_time_sec     stop_name  \
# 0    70001             0  Forest Hills        684.672269  Forest Hills
# 1    70001             1     Oak Grove        519.148623  Forest Hills
# 2    70002             0  Forest Hills        521.140717  Green Street
# 3    70003             1     Oak Grove        512.021927  Green Street
# 4    70004             0  Forest Hills        521.435207   Stony Brook
#
#                                    stop_desc    line
# 0                 Forest Hills - Orange Line  orange
# 1                 Forest Hills - Orange Line  orange
# 2  Green Street - Orange Line - Forest Hills  orange
# 3     Green Street - Orange Line - Oak Grove  orange
# 4   Stony Brook - Orange Line - Forest Hills  orange
#    stop_id  direction_id   destination  headway_time_sec     stop_name  \
# 0    70001             0  Forest Hills        560.257447  Forest Hills
# 1    70001             1     Oak Grove        538.074998  Forest Hills
# 2    70002             0  Forest Hills        539.821318  Green Street
# 3    70003             1     Oak Grove        531.558340  Green Street
# 4    70004             0  Forest Hills        540.200726   Stony Brook
#
#                                    stop_desc    line
# 0                 Forest Hills - Orange Line  orange
# 1                 Forest Hills - Orange Line  orange
# 2  Green Street - Orange Line - Forest Hills  orange
# 3     Green Street - Orange Line - Oak Grove  orange
# 4   Stony Brook - Orange Line - Forest Hills  orange
#    stop_id  direction_id   destination  headway_time_sec     stop_name  \
# 0    70001             0  Forest Hills        532.000000  Forest Hills
# 1    70001             1     Oak Grove        568.392724  Forest Hills
# 2    70002             0  Forest Hills        569.730113  Green Street
# 3    70003             1     Oak Grove        563.100133  Green Street
# 4    70004             0  Forest Hills        570.394914   Stony Brook
#
#                                    stop_desc    line
# 0                 Forest Hills - Orange Line  orange
# 1                 Forest Hills - Orange Line  orange
# 2  Green Street - Orange Line - Forest Hills  orange
# 3     Green Street - Orange Line - Oak Grove  orange
# 4   Stony Brook - Orange Line - Forest Hills  orange
#    stop_id  direction_id   destination  headway_time_sec     stop_name  \
# 0    70001             0  Forest Hills        547.000000  Forest Hills
# 1    70001             1     Oak Grove        593.277430  Forest Hills
# 2    70002             0  Forest Hills        589.646489  Green Street
# 3    70003             1     Oak Grove        588.729268  Green Street
# 4    70004             0  Forest Hills        590.257927   Stony Brook
#
#                                    stop_desc    line
# 0                 Forest Hills - Orange Line  orange
# 1                 Forest Hills - Orange Line  orange
# 2  Green Street - Orange Line - Forest Hills  orange
# 3     Green Street - Orange Line - Oak Grove  orange
# 4   Stony Brook - Orange Line - Forest Hills  orange

# %%
def assign_line_from_description(row):
    if row['line'] == 'unknown':
        # Check if stop_desc is a string before calling lower()
        if isinstance(row['stop_desc'], str):
            desc_lower = row['stop_desc'].lower()
            if 'red' in desc_lower:
                return 'red'
            elif 'green' in desc_lower:
                return 'green'
            elif 'blue' in desc_lower:
                return 'blue'
            elif 'orange' in desc_lower:
                return 'orange'
    return row['line']

for i in dfs:
    df = dfs[i]
    df['line'] = df.apply(assign_line_from_description, axis=1)

# %% [markdown]
# Write the cleaned data to csv file

# %%
for i in dfs:
    df = dfs[i]
    df.to_csv(f"Data\Headways_{i}_cleaned.csv")
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\H'
# <>:3: SyntaxWarning: invalid escape sequence '\H'
# C:\Users\arosenolan\AppData\Local\Temp\ipykernel_25636\1401475552.py:3: SyntaxWarning: invalid escape sequence '\H'
#   df.to_csv(f"Data\Headways_{i}_cleaned.csv")

# %% [markdown]
# Compile all csv files into one.

# %%
combined_dfs = []

for year in dfs:
    df = dfs[year]
    # Add a 'year' column to each DataFrame
    df['year'] = year
    combined_dfs.append(df)

# Concatenate all DataFrames vertically
combined_df = pd.concat(combined_dfs, ignore_index=True)

# Save to CSV
combined_df.to_csv('Headways_cleaned.csv', index=False)
